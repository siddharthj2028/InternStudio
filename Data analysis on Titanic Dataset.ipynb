# %%
import pandas as pd

# %%
#import datast 
titanic = pd.read_csv('train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # drop duplicates

# %%
titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # check for null values

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
null_counts = titanic.isnull().sum()
if null_counts.any():
    print(null_counts[null_counts>0])
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# # data Cleaning and Missing Values Handling:

# %%
# if number of entires is N, you have less than 5-10% missing values -- WE CAN ELIMINATE THOSE ROWS 
titanic = titanic[titanic['Embarked'].notna()]

# %%
null_counts = titanic.isnull().sum()
if null_counts.any():
    print(null_counts[null_counts>0])
# Out:
# Age      177
# Cabin    687
# dtype: int64

# %%
# if the number id N, you have 30 - 50% missing values -we can replace the rows with mean, median, mode
titanic['Age'].fillna(titanic['Age'].median(), inplace = True)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_18532\4242329894.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(titanic['Age'].median(), inplace = True)
# C:\Users\siddh\AppData\Local\Temp\ipykernel_18532\4242329894.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
null_counts = titanic.isnull().sum()
if null_counts.any():
    print(null_counts[null_counts>0])
# Out:
# Cabin    687
# dtype: int64

# %%
#if the number of entries is N, you have above 70% missing values --use some intuition and eliminate the coloumn
#(687/891)*100 = 77.10%
titanic = titanic.drop("Cabin",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 3
#       1 #if the number of entries is N, you have above 70% missing values --use some intuition and eliminate the coloumn
#       2 #(687/891)*100 = 77.10%
# ----> 3 titanic = titanic.drop("Cabin",axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True, drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # check the coloumns

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
titanic["Age"] = titanic["Age"].astype("int64")
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %% [markdown]
# # detecting outliers using data visualization/seaborn

# %%
import seaborn as sns 
sns.boxplot(titanic["Survived"])
# every value is B/W 0 - 1 ( suggesting 0 is dead and 1 is survived)
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.boxplot(titanic["Pclass"])
# everything is divided between 1,2,3 and no pointers detected so no outliers
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(titanic["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(titanic["SibSp"])
# outliers are detected greater than 7
# Out:
# <Axes: ylabel='SibSp'>

# %%
sns.boxplot(titanic["Fare"])
# outliers are detected 
titanic = titanic[titanic["Fare"]<500]

# %%
import numpy as np

# %%
z_scores = np.abs((titanic[["Age","SibSp"]]-titanic[["Age","SibSp"]].mean())/titanic[["Age","SibSp"]].std())
outliers_threshold = 3
outliers = titanic[(z_scores['Age']>outliers_threshold) | (z_scores['SibSp']>outliers_threshold)]
print(outliers)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 16            17         0       3                     Rice, Master. Eugene
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 67            69         1       3          Andersson, Miss. Erna Alexandra
# 70            72         0       3               Goodwin, Miss. Lillian Amy
# 95            97         0       1                Goldschmidt, Mr. George B
# 115          117         0       3                     Connors, Mr. Patrick
# 118          120         0       3        Andersson, Miss. Ellis Anna Maria
# 158          160         0       3               Sage, Master. Thomas Henry
# 163          165         0       3             Panula, Master. Eino Viljami
# 170          172         0       3                     Rice, Master. Arthur
# ...

# %%
# winsorize the outliers by replacing hem with the 95th percentile value
age_threshold  = titanic["Age"].quantile(0.95)
SibSp_threshold  = titanic["SibSp"].quantile(0.95)

titanic["Age"] = np.where(titanic["Age"]>age_threshold, age_threshold, titanic["Age"])
titanic["SibSp"] = np.where(titanic["SibSp"]>SibSp_threshold, SibSp_threshold, titanic["SibSp"])

# %%
#drop unneseccary coloumns

titanic.drop(["PassengerId","Name","Ticket"],axis = 1, inplace=True)

# %%
titanic.drop_duplicates(inplace = True)
titanic.reset_index(inplace = True, drop = True)
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0    1.0      0   7.2500        S
# 1           1       1  female  38.0    1.0      0  71.2833        C
# 2           1       3  female  26.0    0.0      0   7.9250        S
# 3           1       1  female  35.0    1.0      0  53.1000        S
# 4           0       3    male  35.0    0.0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 756         0       3  female  39.0    0.0      5  29.1250        Q
# 757         1       1  female  19.0    0.0      0  30.0000        S
# 758         0       3  female  28.0    1.0      2  23.4500        S
# 759         1       1    male  26.0    0.0      0  30.0000        C
# 760         0       3    male  32.0    0.0      0   7.7500        Q
#
# [761 rows x 8 columns]

# %%
#group by

survived = titanic.groupby("Survived").mean(numeric_only = True)
survived
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.489933  29.689038  0.492170  0.378076  24.181226
# 1         1.923567  27.808917  0.484076  0.496815  45.829738

# %%
#filtering

female_passengers = titanic[titanic.Sex == "female"]
female_passengers

hihg_value_passengers = titanic[titanic.Fare > 35]
hihg_value_passengers
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 1           1       1  female  38.0    1.0      0   71.2833        C
# 3           1       1  female  35.0    1.0      0   53.1000        S
# 6           0       1    male  54.0    0.0      0   51.8625        S
# 23          1       1    male  28.0    0.0      0   35.5000        S
# 27          0       1    male  19.0    3.0      2  263.0000        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 731         1       1  female  16.0    0.0      1   39.4000        S
# 734         1       1  female  45.0    1.0      1  164.8667        S
# 743         0       1    male  31.0    0.0      0   50.4958        S
# 745         1       1  female  47.0    1.0      1   52.5542        S
# 751         1       1  female  54.0    0.0      1   83.1583        C
#
# [183 rows x 8 columns]

# %% [markdown]
# # visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.histplot(data=titanic, x="Age",hue="Survived",kde=True)
plt.title("distribution of passengers by age and survived")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=titanic, x="Pclass",hue="Survived")
plt.title("Distribution passengers by age and survival")
plt.show()
